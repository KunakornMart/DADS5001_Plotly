# %% [markdown]
# <a href="https://colab.research.google.com/github/KunakornMart/DADS5001_Plotly/blob/main/Assignment_Plotly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv("https://github.com/KunakornMart/DADS5001_Plotly/blob/main/Beer_FG_Feb2024.csv?raw=True")
df
# Out:
#    Month_Year      Product              Production              Detail  \
# 0    FEB_2024  Singha 5.0%           BEER BT 620ml                Malt
# 1    FEB_2024  Singha 5.0%           BEER BT 620ml                 Hop
# 2    FEB_2024  Singha 5.0%           BEER BT 620ml               Syrup
# 3    FEB_2024  Singha 5.0%           BEER BT 620ml                Fuel
# 4    FEB_2024  Singha 5.0%           BEER BT 620ml     Power&Utilities
# ..        ...          ...                     ...                 ...
# 69   FEB_2024  Singha 5.0%  BEER BT 320ml (Export)               Label
# 70   FEB_2024  Singha 5.0%  BEER BT 320ml (Export)              Bottle
# 71   FEB_2024  Singha 5.0%  BEER BT 320ml (Export)               Crown
# 72   FEB_2024  Singha 5.0%  BEER BT 320ml (Export)     Packaging-Other
# 73   FEB_2024  Singha 5.0%  BEER BT 320ml (Export)  Repair&Maintenance
#
#      Actual  Standard
# 0    3.9909    3.4870
# 1    0.7930    0.9132
# 2    0.8474    0.8464
# ...

# %%
df2 = pd.DataFrame([df.groupby("Production")["Standard"].sum()])
df2=df2.T
df2.reset_index(inplace=True)
df2
# Out:
#                Production  Standard
# 0           BEER BT 320ml   73.3079
# 1  BEER BT 320ml (Export)   21.3356
# 2  BEER BT 330ml (Export)   20.5766
# 3           BEER BT 620ml   64.2201
# 4  BEER BT 620ml (Export)   18.1669
# 5  BEER BT 630ml (Export)   18.3046

# %%
fig = px.bar(df, x="Production", y="Actual", color="Detail", title="Singha Beer Finish Cost (Baht/Litre)")

fig.add_trace(
    go.Scatter(
        mode='markers',
        x = df2['Production'],
        y = df2['Standard'],
        name="Percentage Cases",
        line=go.scatter.Line(color="gray"),
        marker_color='red',
        showlegend=False
    )
        # x=[2, 4],
        # y=[4, 8],
        # mode="lines",
        # line=go.scatter.Line(color="gray"),
        # showlegend=False)
)

fig.update_traces(
    marker=dict(size=50, symbol="line-ew", line=dict(width=4, color="Red")),
    selector=dict(mode="markers"),
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
